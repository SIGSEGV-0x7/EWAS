# %%
import pandas as pd
import re

data = pd.read_csv("origin_surt_url.csv", names=["origin", "surt"], header=None)
data
# Out:
#                                                   origin  \
# 0                               http://017uk.cf/2015/07/
# 1                     http://1000.menu/catalog/pasternak
# 2                               http://1007.show758.com/
# 3      http://1008643.r.msn.com/?ld=DvQPxAuuX-lOKv4Uv...
# 4      http://1019ampradio.cbslocal.com/tag/johnny-gi...
# ...                                                  ...
# 60740  https://zh.wikipedia.org/wiki/Category:%E8%82%...
# 60741  https://zh.wikipedia.org/zh-hk/%E5%A1%9E%E5%88...
# 60742  https://zh.wikipedia.org/zh-tw/%E6%AD%A3%E7%BE...
# 60743  https://zh.wiktionary.org/wiki/%D1%81%D0%BD%D0...
# 60744              https://zh.wiktionary.org/wiki/brecha
#
#                                                     surt
# 0                            http://(cf,017uk,)/2015/07/
# 1                  http://(menu,1000,)/catalog/pasternak
# 2                            http://(com,show758,1007,)/
# 3      http://(com,msn,r,1008643,)/?ld=dvqpxauux-lokv...
# 4      http://(com,cbslocal,1019ampradio,)/tag/johnny...
# ...                                                  ...
# 60740  https://(org,wikipedia,zh,)/wiki/category:%e8%...
# 60741  https://(org,wikipedia,zh,)/zh-hk/%e5%a1%9e%e5...
# 60742  https://(org,wikipedia,zh,)/zh-tw/%e6%ad%a3%e7...
# 60743  https://(org,wiktionary,zh,)/wiki/%d1%81%d0%bd...
# 60744           https://(org,wiktionary,zh,)/wiki/brecha
#
# [60745 rows x 2 columns]

# %%
data["origin_clean"] = data["origin"].apply(lambda url : re.sub('[^A-Za-z0-9]+', '', url[5:]))
data
# Out:
#                                                   origin  \
# 0                               http://017uk.cf/2015/07/
# 1                     http://1000.menu/catalog/pasternak
# 2                               http://1007.show758.com/
# 3      http://1008643.r.msn.com/?ld=DvQPxAuuX-lOKv4Uv...
# 4      http://1019ampradio.cbslocal.com/tag/johnny-gi...
# ...                                                  ...
# 60740  https://zh.wikipedia.org/wiki/Category:%E8%82%...
# 60741  https://zh.wikipedia.org/zh-hk/%E5%A1%9E%E5%88...
# 60742  https://zh.wikipedia.org/zh-tw/%E6%AD%A3%E7%BE...
# 60743  https://zh.wiktionary.org/wiki/%D1%81%D0%BD%D0...
# 60744              https://zh.wiktionary.org/wiki/brecha
#
#                                                     surt  \
# 0                            http://(cf,017uk,)/2015/07/
# 1                  http://(menu,1000,)/catalog/pasternak
# 2                            http://(com,show758,1007,)/
# 3      http://(com,msn,r,1008643,)/?ld=dvqpxauux-lokv...
# 4      http://(com,cbslocal,1019ampradio,)/tag/johnny...
# ...                                                  ...
# 60740  https://(org,wikipedia,zh,)/wiki/category:%e8%...
# 60741  https://(org,wikipedia,zh,)/zh-hk/%e5%a1%9e%e5...
# 60742  https://(org,wikipedia,zh,)/zh-tw/%e6%ad%a3%e7...
# 60743  https://(org,wiktionary,zh,)/wiki/%d1%81%d0%bd...
# 60744           https://(org,wiktionary,zh,)/wiki/brecha
#
#                                             origin_clean
# 0                                          017ukcf201507
# 1                               1000menucatalogpasternak
# 2                                         1007show758com
# 3      1008643rmsncomldDvQPxAuuXlOKv4UvMDiEi4jVUCUwsO...
# 4                  1019ampradiocbslocalcomtagjohnnygill2
# ...                                                  ...
# 60740  zhwikipediaorgwikiCategoryE882B2E7A9BAE59CB0E7...
# 60741  zhwikipediaorgzhhkE5A19EE588A9E7B1B3E880B6E6B8...
# 60742         zhwikipediaorgzhtwE6ADA3E7BEA9E881AFE79B9F
# 60743  zhwiktionaryorgwikiD181D0BDD0BED188D0B5D0BDD0B...
# 60744                          zhwiktionaryorgwikibrecha
#
# [60745 rows x 3 columns]

# %%
data.drop("surt", axis = 1).to_csv("origin_simpleclean.csv", header = False, index = False)
